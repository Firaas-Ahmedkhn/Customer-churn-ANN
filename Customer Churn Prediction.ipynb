# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sn

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5232  1755-RMCXH    Male              0     Yes        Yes       2
# 4714  0016-QLJIS  Female              0     Yes        Yes      65
# 5285  9479-HYNYL  Female              0     Yes         No      71
# 1670  5047-LHVLY    Male              1      No        Yes       1
# 3193  1407-DIGZV  Female              0     Yes        Yes       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5232          Yes            No              No  No internet service  ...
# 4714          Yes           Yes             DSL                  Yes  ...
# 5285          Yes            No             DSL                   No  ...
# 1670          Yes            No             DSL                   No  ...
# 3193          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5232  No internet service  No internet service  No internet service
# 4714                  Yes                  Yes                  Yes
# 5285                  Yes                  Yes                  Yes
# 1670                  Yes                   No                   No
# 3193  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5232  No internet service  Month-to-month               No
# 4714                  Yes        Two year              Yes
# 5285                  Yes        Two year              Yes
# 1670                   No  Month-to-month              Yes
# 3193  No internet service        Two year               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 5232             Mailed check          20.30         40.25    No
# 4714             Mailed check          90.45        5957.9    No
# 5285  Credit card (automatic)          80.70       5705.05    No
# 1670             Mailed check          50.15         50.15   Yes
# 3193             Mailed check          19.10            52    No
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)  #Because it is useless in this case

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4524    Male              0     Yes         No      23          Yes
# 2535  Female              1     Yes         No      70          Yes
# 3646    Male              0      No         No      39          Yes
# 6498  Female              0      No         No       1          Yes
# 2954  Female              0      No         No       7          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 4524           Yes     Fiber optic            Yes          Yes
# 2535           Yes             DSL            Yes          Yes
# 3646            No     Fiber optic             No           No
# 6498            No     Fiber optic             No          Yes
# 2954           Yes     Fiber optic             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 4524              Yes          No         Yes              No  Month-to-month
# 2535              Yes         Yes         Yes             Yes        Two year
# 3646              Yes         Yes          No              No        One year
# 6498              Yes          No          No              No  Month-to-month
# 2954               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 4524              Yes           Electronic check           99.25       2186.4
# 2535              Yes  Bank transfer (automatic)           92.20      6474.45
# 3646               No           Electronic check           81.90      3219.75
# 6498              Yes           Electronic check           82.30         82.3
# 2954               No               Mailed check           75.45       480.75
#
#      Churn
# 4524   Yes
# 2535    No
# 3646    No
# 6498   Yes
# 2954   Yes

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# File ~\Lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~\Lib\site-packages\pandas\_libs\lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df1 = df[df.TotalCharges!=' ']

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\firaa\AppData\Local\Temp\ipykernel_39204\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
df1.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines        object
# InternetService      object
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract             object
# PaperlessBilling      int64
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %% [markdown]
# ## Data Visualization

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number of Customer")
plt.title("Customer Churn Prediction Visualization")

plt.hist([tenure_churn_no, tenure_churn_yes], color=['red', 'green'], label = ['Churn=No', 'churn=Yes'])
plt.legend()

# %%
def print_unique_value(df):
    for column in df:
        if df[column].dtype=='object':
            print(f'{column}: {df[column].unique()}')

# %%
print_unique_value(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service', 'No', inplace=True)
df1.replace('No phone service', 'No', inplace=True)
# Out:
# C:\Users\firaa\AppData\Local\Temp\ipykernel_39204\4245438437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace=True)
# C:\Users\firaa\AppData\Local\Temp\ipykernel_39204\4245438437.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace=True)

# %%
print_unique_value(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner', 'Dependents', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
               'StreamingMovies', 'PaperlessBilling', 'Churn', 'MultipleLines']

# %%
for col in yes_no_columns:
    df1[col].replace({'Yes':1, 'No':0}, inplace=True)
# Out:
# C:\Users\firaa\AppData\Local\Temp\ipykernel_39204\2306103964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1, 'No':0}, inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# C:\Users\firaa\AppData\Local\Temp\ipykernel_39204\698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2 = pd.get_dummies(data=df1, columns = ['InternetService', 'Contract', 'PaymentMethod'])

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5171       1              0        1           0      12             1
# 315        0              0        1           1      51             1
# 6077       1              0        1           0      62             1
# 659        0              0        1           0      37             1
# 1483       1              0        1           1      51             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5171              0               0             0                 0  ...
# 315               1               1             1                 0  ...
# 6077              1               1             1                 1  ...
# 659               0               0             0                 0  ...
# 1483              0               1             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5171                 True                        False               False
# 315                 False                         True               False
# 6077                False                         True               False
# 659                 False                        False                True
# 1483                 True                        False               False
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5171                     True              False              False
# 315                     False               True              False
# 6077                    False              False               True
# 659                      True              False              False
# 1483                    False               True              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5171                                     True
# 315                                     False
# 6077                                    False
# 659                                      True
# 1483                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5171                                  False                           False
# 315                                    True                           False
# 6077                                  False                           False
# 659                                   False                           False
# 1483                                   True                           False
#
#       PaymentMethod_Mailed check
# 5171                       False
# 315                        False
# 6077                        True
# 659                        False
# 1483                       False
#
# [5 rows x 27 columns]

# %%
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']
Scaler = MinMaxScaler()
df2[cols_to_scale] = Scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [ True False]
# InternetService_Fiber optic: [False  True]
# InternetService_No: [False  True]
# Contract_Month-to-month: [ True False]
# Contract_One year: [False  True]
# Contract_Two year: [False  True]
# PaymentMethod_Bank transfer (automatic): [False  True]
# PaymentMethod_Credit card (automatic): [False  True]
# PaymentMethod_Electronic check: [ True False]
# PaymentMethod_Mailed check: [False  True]

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 2482       1              0        1           0  0.014085             1
# 6580       1              0        1           1  0.676056             1
# 1670       0              1        0           1  0.000000             1
# 2480       0              1        1           0  0.816901             1
# 1397       1              0        0           0  0.042254             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2482              0               0             0                 0  ...
# 6580              0               0             1                 1  ...
# 1670              0               0             0                 1  ...
# 2480              1               0             0                 0  ...
# 1397              0               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2482                 True                        False               False
# 6580                 True                        False               False
# 1670                 True                        False               False
# 2480                False                         True               False
# 1397                False                         True               False
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2482                     True              False              False
# 6580                    False               True              False
# 1670                     True              False              False
# 2480                     True              False              False
# 1397                     True              False              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2482                                    False
# 6580                                    False
# 1670                                    False
# 2480                                     True
# 1397                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2482                                  False                            True
# 6580                                   True                           False
# 1670                                  False                           False
# 2480                                  False                           False
# 1397                                   True                           False
#
#       PaymentMethod_Mailed check
# 2482                       False
# 6580                       False
# 1670                        True
# 2480                       False
# 1397                       False
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Train test split

# %%
X = df2.drop('Churn', axis='columns')
y = df2['Churn']
X = X.astype('float32')  # Ensure X is float32
y = y.astype('float32')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
y_train.shape
# Out:
# (5625,)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664     1.0            1.0      0.0         0.0  0.126761           1.0
# 101      1.0            0.0      1.0         1.0  0.000000           1.0
# 2621     0.0            0.0      1.0         0.0  0.985915           1.0
# 392      1.0            1.0      0.0         0.0  0.014085           1.0
# 1327     0.0            0.0      1.0         0.0  0.816901           1.0
# 3607     1.0            0.0      0.0         0.0  0.169014           1.0
# 2773     0.0            0.0      1.0         0.0  0.323944           0.0
# 1936     1.0            0.0      1.0         0.0  0.704225           1.0
# 5387     0.0            0.0      0.0         0.0  0.042254           0.0
# 4331     0.0            0.0      0.0         0.0  0.985915           1.0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664            0.0             0.0           0.0               1.0  ...
# 101             0.0             0.0           0.0               0.0  ...
# 2621            0.0             0.0           1.0               1.0  ...
# 392             0.0             0.0           0.0               0.0  ...
# 1327            1.0             0.0           0.0               1.0  ...
# 3607            0.0             1.0           0.0               0.0  ...
# 2773            0.0             0.0           0.0               1.0  ...
# 1936            0.0             1.0           1.0               0.0  ...
# 5387            0.0             0.0           0.0               0.0  ...
# 4331            1.0             0.0           0.0               0.0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                  0.0                          1.0                 0.0
# 101                   0.0                          0.0                 1.0
# 2621                  1.0                          0.0                 0.0
# 392                   1.0                          0.0                 0.0
# 1327                  0.0                          1.0                 0.0
# 3607                  1.0                          0.0                 0.0
# 2773                  1.0                          0.0                 0.0
# 1936                  1.0                          0.0                 0.0
# 5387                  1.0                          0.0                 0.0
# 4331                  0.0                          0.0                 1.0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                      1.0                0.0                0.0
# 101                       1.0                0.0                0.0
# 2621                      0.0                0.0                1.0
# 392                       1.0                0.0                0.0
# 1327                      0.0                1.0                0.0
# 3607                      0.0                1.0                0.0
# 2773                      1.0                0.0                0.0
# 1936                      0.0                1.0                0.0
# 5387                      1.0                0.0                0.0
# 4331                      0.0                0.0                1.0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                      0.0
# 101                                       0.0
# 2621                                      0.0
# 392                                       0.0
# 1327                                      1.0
# 3607                                      0.0
# 2773                                      0.0
# 1936                                      1.0
# 5387                                      0.0
# 4331                                      1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                    1.0                             0.0
# 101                                     0.0                             1.0
# 2621                                    1.0                             0.0
# 392                                     0.0                             1.0
# 1327                                    0.0                             0.0
# 3607                                    0.0                             0.0
# 2773                                    0.0                             1.0
# 1936                                    0.0                             0.0
# 5387                                    0.0                             1.0
# 4331                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 5664                         0.0
# 101                          0.0
# 2621                         0.0
# 392                          0.0
# 1327                         0.0
# 3607                         1.0
# 2773                         0.0
# 1936                         0.0
# 5387                         0.0
# 4331                         0.0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
X_train.dtypes
# Out:
# gender                                     float32
# SeniorCitizen                              float32
# Partner                                    float32
# Dependents                                 float32
# tenure                                     float32
# PhoneService                               float32
# MultipleLines                              float32
# OnlineSecurity                             float32
# OnlineBackup                               float32
# DeviceProtection                           float32
# TechSupport                                float32
# StreamingTV                                float32
# StreamingMovies                            float32
# PaperlessBilling                           float32
# MonthlyCharges                             float32
# TotalCharges                               float32
# InternetService_DSL                        float32
# InternetService_Fiber optic                float32
# InternetService_No                         float32
# Contract_Month-to-month                    float32
# Contract_One year                          float32
# Contract_Two year                          float32
# PaymentMethod_Bank transfer (automatic)    float32
# PaymentMethod_Credit card (automatic)      float32
# PaymentMethod_Electronic check             float32
# PaymentMethod_Mailed check                 float32
# dtype: object

# %%
model = Sequential([
    Dense(units=25, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(units=15, activation='relu'),
    Dense(units=1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 1ms/step - loss: 0.5056 - accuracy: 0.7531
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4248 - accuracy: 0.7964
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8043
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8055
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4128 - accuracy: 0.8048
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4108 - accuracy: 0.8059
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8087
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4076 - accuracy: 0.8098
# Epoch 9/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8087
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8094
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4027 - accuracy: 0.8100
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4020 - accuracy: 0.8114
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3999 - accuracy: 0.8119
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8148
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8119
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8137
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8146
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3933 - accuracy: 0.8158
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8156
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3913 - accuracy: 0.8178
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3896 - accuracy: 0.8160
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8183
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8194
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3860 - accuracy: 0.8188
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8192
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8201
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8144
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3825 - accuracy: 0.8203
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8185
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8199
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8219
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3791 - accuracy: 0.8210
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.8224
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8215
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3777 - accuracy: 0.8235
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8229
# Epoch 37/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8238
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8242
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8242
# Epoch 40/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3750 - accuracy: 0.8220
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3735 - accuracy: 0.8245
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3730 - accuracy: 0.8244
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3723 - accuracy: 0.8276
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3720 - accuracy: 0.8263
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3707 - accuracy: 0.8267
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8261
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3702 - accuracy: 0.8247
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3679 - accuracy: 0.8293
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3694 - accuracy: 0.8261
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.8265
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8300
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3670 - accuracy: 0.8274
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8247
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3663 - accuracy: 0.8295
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3641 - accuracy: 0.8295
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8293
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3644 - accuracy: 0.8299
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3637 - accuracy: 0.8313
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8276
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3622 - accuracy: 0.8309
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3616 - accuracy: 0.8293
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8292
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8316
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3594 - accuracy: 0.8336
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3589 - accuracy: 0.8315
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3588 - accuracy: 0.8320
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3597 - accuracy: 0.8309
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8332
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8311
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8332
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3567 - accuracy: 0.8315
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3586 - accuracy: 0.8292
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3570 - accuracy: 0.8316
# Epoch 74/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3546 - accuracy: 0.8329
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3550 - accuracy: 0.8311
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8320
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3533 - accuracy: 0.8345
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8322
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3534 - accuracy: 0.8340
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8329
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8347
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8354
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3502 - accuracy: 0.8375
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8361
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8359
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8366
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8386
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8361
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3474 - accuracy: 0.8357
# Epoch 90/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3481 - accuracy: 0.8357
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3475 - accuracy: 0.8357
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3457 - accuracy: 0.8370
# Epoch 93/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3460 - accuracy: 0.8370
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8375
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8354
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3456 - accuracy: 0.8393
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3450 - accuracy: 0.8391
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3440 - accuracy: 0.8405
# Epoch 99/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3436 - accuracy: 0.8427
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.8361

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4912 - accuracy: 0.7726
# [0.49116992950439453, 0.7725657224655151]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.14507277],
#        [0.60167533],
#        [0.00514983],
#        [0.78622365],
#        [0.5338208 ]], dtype=float32)

# %%
y_test[:10]
# Out:
# 2660    0.0
# 744     0.0
# 5579    1.0
# 64      1.0
# 3287    1.0
# 816     1.0
# 2670    0.0
# 5920    0.0
# 1023    0.0
# 6087    0.0
# Name: Churn, dtype: float32

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    if element < 0.5:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 1, 1, 0, 0, 0, 0]

# %% [markdown]
# ## Performance of overall model

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.87      0.84       999
#          1.0       0.63      0.53      0.57       408
#
#     accuracy                           0.77      1407
#    macro avg       0.72      0.70      0.71      1407
# weighted avg       0.76      0.77      0.77      1407

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Test")
# Out:
# Text(95.72222222222221, 0.5, 'Test')
